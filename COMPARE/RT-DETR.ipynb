# %%
# pip install supervision==0.26.1 --force-reinstall --no-deps # 1

# %%
# Только ключевые метрики
watch -n 1 'nvidia-smi --query-gpu=memory.used,memory.total,utilization.gpu,temperature.gpu --format=csv'

# %%
https://github.com/pyresearch/notebooks

# %%
https://colab.research.google.com/github/pyresearch/notebooks/blob/main/notebook/how_to_finetune_rf_detr_on_detection_dataset.ipynb

# %%
# !pwd
# Out:
# /home/oleg/projects/ML/RT-DETR-RF-DETR

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="1xSkA1WLYlGLbcHdbDla")
project = rf.workspace("uav-qnoms").project("uav-wqshy")
version = project.version(6)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in UAV-6 to yolov11:: 100%|██████████████| 255195/255195 [00:18<00:00, 13565.78it/s]
# Extracting Dataset Version Zip to UAV-6 in yolov11:: 100%|█████████████████| 16446/16446 [00:00<00:00, 17411.19it/s]

# %%
# модели доступны

    'rtdetr-l.pt',
    'rtdetr-x.pt', 
    'rtdetr-m.pt',
    'rtdetr-s.pt'
]

for model_name in models_to_try:
    try:
        model = RTDETR(model_name)
        print(f"✅ Доступна: {model_name}")
        break
    except:
        print(f"❌ Недоступна: {model_name}")
# Out:
# ✅ Доступна: rtdetr-l.pt

# %%
from ultralytics import RTDETR

# Load a COCO-pretrained RT-DETR-l model
model = RTDETR("rtdetr-l.pt")
#model = RTDETR('rtdetr-m.pt')  # ⬅️ Быстрее
# model = RTDETR('rtdetr-s.pt')  # ⬅️ Намного быстрее

# Display model information (optional)
model.info()
# Out:
# rt-detr-l summary: 449 layers, 32,970,476 parameters, 0 gradients, 108.3 GFLOPs
# (449, 32970476, 0, 108.3437056)

# %%
from ultralytics import RTDETR

results = model.train(data="/home/oleg/projects/ML/RT-DETR-RF-DETR/UAV-6_YOLO11/data.yaml",
                    epochs=30,
                    batch=12,     # Средний batch  
                    imgsz=640, #640,
                    #half=True,           # ⬅️ FP16 precision (осторожно!) 
                    profile=True,        # ⬅️ Покажет что тормозит  
                    #compile=True,  # ⬅️ УСКОРЯЕТ В 1.5-2 РАЗА!
                    #workers=16,  
                    #cache=True,   # Кеширование
                    project='uav_detection_project',
                    name='exp_rt-detr_l_',  
                    amp=True) # Mixed precision
# Out:
# New https://pypi.org/project/ultralytics/8.3.223 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.221 🚀 Python-3.11.14 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=12, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/oleg/projects/ML/RT-DETR-RF-DETR/UAV-6_YOLO11/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=rtdetr-l.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=exp_rt-detr_l_10, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=True, project=uav_detection_project, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/oleg/projects/ML/COMPARE/uav_detection_project/exp_rt-detr_l_10, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
# WARNING ⚠️ no model scale passed. Assuming scale='l'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1     25248  ultralytics.nn.modules.block.HGStem          [3, 32, 48]
#   1                  -1  6    155072  ultralytics.nn.modules.block.HGBlock         [48, 48, 128, 3, 6]
#   2                  -1  1      1408  ultralytics.nn.modules.conv.DWConv           [128, 128, 3, 2, 1, False]
#   3                  -1  6    839296  ultralytics.nn.modules.block.HGBlock         [128, 96, 512, 3, 6]
#   4                  -1  1      5632  ultralytics.nn.modules.conv.DWConv           [512, 512, 3, 2, 1, False]
#   5                  -1  6   1695360  ultralytics.nn.modules.block.HGBlock         [512, 192, 1024, 5, 6, True, False]
#   6                  -1  6   2055808  ultralytics.nn.modules.block.HGBlock         [1024, 192, 1024, 5, 6, True, True]
#   7                  -1  6   2055808  ultralytics.nn.modules.block.HGBlock         [1024, 192, 1024, 5, 6, True, True]
#   8                  -1  1     11264  ultralytics.nn.modules.conv.DWConv           [1024, 1024, 3, 2, 1, False]
#   9                  -1  6   6708480  ultralytics.nn.modules.block.HGBlock         [1024, 384, 2048, 5, 6, True, False]
#  10                  -1  1    524800  ultralytics.nn.modules.conv.Conv             [2048, 256, 1, 1, None, 1, 1, False]
#  11                  -1  1    789760  ultralytics.nn.modules.transformer.AIFI      [256, 1024, 8]
#  12                  -1  1     66048  ultralytics.nn.modules.conv.Conv             [256, 256, 1, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14                   7  1    262656  ultralytics.nn.modules.conv.Conv             [1024, 256, 1, 1, None, 1, 1, False]
#  15            [-2, -1]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  3   2232320  ultralytics.nn.modules.block.RepC3           [512, 256, 3]
#  17                  -1  1     66048  ultralytics.nn.modules.conv.Conv             [256, 256, 1, 1]
#  18                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  19                   3  1    131584  ultralytics.nn.modules.conv.Conv             [512, 256, 1, 1, None, 1, 1, False]
#  20            [-2, -1]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   2232320  ultralytics.nn.modules.block.RepC3           [512, 256, 3]
#  22                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  23            [-1, 17]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  24                  -1  3   2232320  ultralytics.nn.modules.block.RepC3           [512, 256, 3]
#  25                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  26            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  27                  -1  3   2232320  ultralytics.nn.modules.block.RepC3           [512, 256, 3]
#  28        [21, 24, 27]  1   7303907  ultralytics.nn.modules.head.RTDETRDecoder    [1, [256, 256, 256]]
# rt-detr-l summary: 457 layers, 32,808,131 parameters, 32,808,131 gradients, 108.0 GFLOPs
#
# Transferred 926/941 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3276.0±1604.0 MB/s, size: 28.5 KB)
# train: Scanning /home/oleg/projects/ML/RT-DETR-RF-DETR/UAV-6_YOLO11/train/labels.cache... 7503 images, 6 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 7503/7503 11.5Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4445.3±2483.9 MB/s, size: 54.5 KB)
# val: Scanning /home/oleg/projects/ML/RT-DETR-RF-DETR/UAV-6_YOLO11/valid/labels.cache... 477 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 477/477 553.0Kit/s 0.0s
# Plotting labels to /home/oleg/projects/ML/COMPARE/uav_detection_project/exp_rt-detr_l_10/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 143 weight(decay=0.0), 206 weight(decay=0.00046875), 226 bias(decay=0.0)
# MLflow: logging run_id(e4a1a1ce2eff496f83c8a325e322972d) to runs/mlflow
# MLflow: view at http://127.0.0.1:5000 with 'mlflow server --backend-store-uri runs/mlflow'
# MLflow: disable with 'yolo settings mlflow=False'
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/oleg/projects/ML/COMPARE/uav_detection_project/exp_rt-detr_l_10
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#        1/30      9.21G     0.6606      8.204     0.6491         28        640: 0% ──────────── 0/626  1.3s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#        1/30      9.42G     0.5194      1.006     0.3417          4        640: 100% ━━━━━━━━━━━━ 626/626 2.1it/s 4:59<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.3it/s 4.6s0.2s
#                    all        477        548      0.821      0.843      0.822      0.458
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#        2/30      9.69G     0.5993     0.4813     0.3407         21        640: 0% ──────────── 0/626  0.5s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#        2/30      9.69G     0.5136     0.5841     0.3407          9        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:41<0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 3.8it/s 5.2s0.3s
#                    all        477        548      0.865      0.751      0.781      0.429
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#        3/30      9.69G     0.4376     0.6266      0.344         18        640: 0% ──────────── 0/626  0.6s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#        3/30      9.72G     0.5132     0.5851     0.3362          3        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:39<1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.6it/s 4.3s0.2s
#                    all        477        548       0.85      0.812      0.847      0.481
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#        4/30      9.69G     0.5241      0.603     0.3457         18        640: 0% ──────────── 0/626  0.5s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#        4/30      9.72G     0.5031     0.6082     0.3225          5        640: 100% ━━━━━━━━━━━━ 626/626 2.3it/s 4:27<0.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.9it/s 4.1s0.2s
#                    all        477        548      0.851      0.909      0.907      0.536
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#        5/30      9.69G     0.4687      0.507     0.3306         27        640: 0% ──────────── 0/626  0.6s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#        5/30      9.72G     0.4939      0.585     0.3204          5        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:41<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.4it/s 4.6s0.2s
#                    all        477        548      0.894      0.891      0.885      0.546
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#        6/30      9.56G     0.5021     0.5064     0.1684         25        640: 0% ──────────── 0/626  0.6s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#        6/30      9.59G      0.482     0.5611     0.3057          6        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:40<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.3it/s 4.7s0.2s
#                    all        477        548      0.904      0.922      0.912      0.548
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#        7/30       9.7G     0.4734     0.6495     0.4906         25        640: 0% ──────────── 0/626  0.6s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#        7/30      9.73G     0.4741     0.5538     0.2993          5        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:40<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 8.8it/s 2.3s0.5s
#                    all        477        548      0.915      0.923      0.929       0.56
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#        8/30      9.61G     0.4272      0.515     0.2227         22        640: 0% ──────────── 0/626  0.5s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#        8/30      9.64G      0.466     0.5357     0.2973          4        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:42<0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.8it/s 4.2s0.2s
#                    all        477        548       0.92      0.929      0.944      0.587
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#        9/30      9.68G     0.4082     0.5546       0.33         16        640: 0% ──────────── 0/626  0.6s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#        9/30      9.71G     0.4645     0.5272      0.296          4        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:41<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.7it/s 4.2s0.2s
#                    all        477        548       0.87      0.936      0.891      0.546
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       10/30      9.71G     0.4601      0.529     0.2874          4        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:44<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.4it/s 4.5s0.2s
#                    all        477        548      0.935      0.901      0.947      0.585
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       11/30      9.56G     0.3937     0.7157     0.3043         24        640: 0% ──────────── 0/626  0.5s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       11/30      9.59G     0.4532     0.5289      0.289          7        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:43<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.6it/s 4.3s0.2s
#                    all        477        548      0.927      0.891      0.935      0.574
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       12/30      9.68G     0.4918     0.5081     0.2994         23        640: 0% ──────────── 0/626  0.5s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       12/30      9.72G     0.4497     0.5193      0.283          6        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:402.9sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.6it/s 4.3s0.2s
#                    all        477        548      0.925       0.94      0.946      0.597
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       13/30      9.69G     0.4856     0.4785     0.3507         19        640: 0% ──────────── 0/626  0.6s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       13/30      9.72G     0.4432     0.5033     0.2787          7        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:42<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.1it/s 4.8s0.2s
#                    all        477        548      0.919      0.933      0.952      0.598
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       14/30      9.62G     0.4891     0.5578     0.3074         25        640: 0% ──────────── 0/626  0.6s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       14/30      9.65G     0.4396     0.4949     0.2762          6        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:41<0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.4it/s 4.6s0.2s
#                    all        477        548       0.96      0.953      0.969       0.62
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       15/30      9.72G     0.4364     0.4848     0.2737          3        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:432.2ssss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.9it/s 4.1s0.2s
#                    all        477        548      0.957      0.956      0.978      0.641
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       16/30      9.56G      0.476      0.468     0.3353         24        640: 0% ──────────── 0/626  0.5s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       16/30      9.59G     0.4323     0.4756     0.2745          8        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:42<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.3it/s 4.6s0.3s
#                    all        477        548      0.951      0.962      0.972      0.623
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       17/30      9.62G     0.4652     0.4429     0.2492         20        640: 0% ──────────── 0/626  0.5s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       17/30      9.65G     0.4256     0.4801     0.2677          7        640: 100% ━━━━━━━━━━━━ 626/626 2.3it/s 4:321.8sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.7it/s 4.2s0.2s
#                    all        477        548      0.918      0.958      0.955      0.621
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       18/30      9.61G     0.4481     0.5116     0.2916         29        640: 0% ──────────── 0/626  0.5s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       18/30      9.64G     0.4239     0.4782     0.2696          3        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:41<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.7it/s 4.2s0.2s
#                    all        477        548      0.919      0.953       0.94      0.617
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       19/30      9.61G     0.4948     0.3979     0.3568         24        640: 0% ──────────── 0/626  0.5s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       19/30      9.64G     0.4253      0.467     0.2611          3        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:38<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.1it/s 4.8s0.2s
#                    all        477        548      0.949      0.951      0.963      0.631
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       20/30      9.64G     0.4163     0.4623     0.2595          3        640: 100% ━━━━━━━━━━━━ 626/626 2.3it/s 4:37<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.6it/s 4.3s0.2s
#                    all        477        548      0.955      0.963      0.967      0.645
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       21/30      9.55G     0.4934     0.4008     0.1829         18        640: 0% ──────────── 0/626  0.6s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       21/30      9.58G     0.3929     0.3991     0.2634          3        640: 100% ━━━━━━━━━━━━ 626/626 2.3it/s 4:37<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 3.7it/s 5.4s0.3s
#                    all        477        548      0.943      0.967      0.967      0.648
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       22/30      9.69G     0.4221     0.4381      0.245         12        640: 0% ──────────── 0/626  0.5s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       22/30      9.72G     0.3863     0.3967     0.2537          5        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:41<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.3it/s 4.6s0.2s
#                    all        477        548      0.963      0.969      0.982      0.651
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       23/30      9.69G     0.3267     0.5595     0.1169         12        640: 0% ──────────── 0/626  0.5s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       23/30      9.72G     0.3804     0.3917     0.2466          3        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:42<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 12.1it/s 1.7s0.1s
#                    all        477        548      0.962      0.973      0.981      0.655
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       24/30      9.68G     0.3802     0.3704     0.2844         14        640: 0% ──────────── 0/626  0.4s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       24/30      9.71G        nan        nan        nan          3        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:40<0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 5.3it/s 3.8s0.2s
#                    all        477        548          0          0          0          0
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       25/30      9.68G     0.2492     0.3271     0.1772         13        640: 0% ──────────── 0/626  0.6s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       25/30      9.71G      0.375     0.3851     0.2418          3        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:42<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.6it/s 4.3s0.2s
#                    all        477        548          0          0          0          0
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       26/30      9.56G     0.3719     0.3723     0.2924         13        640: 0% ──────────── 0/626  0.6s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       26/30      9.59G        nan        nan        nan          4        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:43<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.8it/s 4.2s0.2s
#                    all        477        548          0          0          0          0
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       27/30      9.62G     0.3496     0.3705     0.1504         14        640: 0% ──────────── 0/626  0.6s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       27/30      9.65G        nan        nan        nan          3        640: 100% ━━━━━━━━━━━━ 626/626 2.3it/s 4:38<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 5.2it/s 3.8s0.2s
#                    all        477        548          0          0          0          0
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       28/30      9.64G     0.4103     0.5984     0.2138         17        640: 0% ──────────── 0/626  0.6s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       28/30      9.68G        nan        nan        nan          4        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:40<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 5.1it/s 4.0s0.2s
#                    all        477        548          0          0          0          0
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       29/30      9.68G     0.3142     0.3859     0.2466         13        640: 0% ──────────── 0/626  0.5s
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       29/30      9.71G        nan        nan        nan          3        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:44<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.5it/s 4.5s0.2s
#                    all        477        548          0          0          0          0
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
# /home/oleg/miniconda3/envs/tensflow/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       30/30      9.64G        nan        nan        nan          3        640: 100% ━━━━━━━━━━━━ 626/626 2.2it/s 4:39<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 5.0it/s 4.0s0.2s
#                    all        477        548          0          0          0          0
#
# 30 epochs completed in 2.382 hours.
# Optimizer stripped from /home/oleg/projects/ML/COMPARE/uav_detection_project/exp_rt-detr_l_10/weights/last.pt, 66.2MB
# Optimizer stripped from /home/oleg/projects/ML/COMPARE/uav_detection_project/exp_rt-detr_l_10/weights/best.pt, 66.2MB
#
# Validating /home/oleg/projects/ML/COMPARE/uav_detection_project/exp_rt-detr_l_10/weights/best.pt...
# Ultralytics 8.3.221 🚀 Python-3.11.14 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# rt-detr-l summary: 302 layers, 31,985,795 parameters, 0 gradients, 103.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.5it/s 4.4s0.2s
#                    all        477        548      0.964      0.973      0.981      0.655
# Speed: 0.1ms preprocess, 6.3ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to /home/oleg/projects/ML/COMPARE/uav_detection_project/exp_rt-detr_l_10
# MLflow: results logged to runs/mlflow
# MLflow: disable with 'yolo settings mlflow=False'

# %%
# Run inference with the RT-DETR-l model on the 'bus.jpg' image
results = model("path/to/bus.jpg")
