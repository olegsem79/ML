# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import make_regression

X, y = make_regression(
    n_samples=100,
    n_features=1, 
    n_informative=1, 
    n_targets=1,
    noise=10,
    random_state=42
)
display(X, y)
# Out:
# array([[ 0.93128012],
#        [ 0.08704707],
#        [-1.05771093],
#        [ 0.31424733],
#        [-0.47917424],
#        [ 0.64768854],
#        [-0.46341769],
#        [ 0.54256004],
#        [ 0.61167629],
#        [ 1.0035329 ],
#        [ 0.8219025 ],
#        [ 1.53803657],
#        [ 0.73846658],
#        [-0.21967189],
#        [-0.8084936 ],
#        [ 0.09176078],
#        [-1.95967012],
#        [ 0.51326743],
#        [ 1.03099952],
#        [-2.6197451 ],
#        [ 0.49671415],
#        [ 0.09707755],
#        [-0.46572975],
#        [ 0.91540212],
#        [ 1.56464366],
#        [ 1.46564877],
#        [-0.60063869],
#        [-0.03582604],
#        [-0.60170661],
#        [-1.19620662],
#        [ 0.35711257],
#        [ 0.37569802],
#        [ 0.26105527],
#        [-0.5297602 ],
#        [-0.90802408],
#        [ 0.19686124],
#        [-0.29900735],
#        [ 0.36163603],
#        [ 0.82254491],
#        [-0.29169375],
#        [ 0.36139561],
# ...
